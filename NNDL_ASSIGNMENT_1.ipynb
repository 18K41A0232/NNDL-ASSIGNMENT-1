# %% [markdown]
# <a href="https://colab.research.google.com/github/18K41A0232/NNDL-ASSIGNMENT-1/blob/main/NNDL_ASSIGNMENT_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Find the global minimum point and value for the function f(x) = x^4 + 3x^2 + 10 1) Do manual calculations for two iterations 2) Find optional solution using python programming
#
# 1)![IMG_20210321_142947.jpg](data:image/jpeg;base64,...)

# %%
from sympy import *
x = symbols('x')
f = x ** 4 + 3 * x ** 2 + 10
y = diff(f, x) 
print(y)
X = int(input("enter x value:"))
itr = 1 
n = 0.1 
epoch = 2
while (itr <= epoch) :
   Y = y.subs(x, X)
   print("y", Y)
   deltax=- n * Y
   print("delta(x) =", deltax)
   newx = X + deltax
   print("x =", newx)
   itr = itr + 1
   X = newx
print("final x =", X)
print("Minimum value is", f.subs(x, X))
# Out:
# 4*x**3 + 6*x
# enter x value:0
# y 0
# delta(x) = 0
# x = 0
# y 0
# delta(x) = 0
# x = 0
# final x = 0
# Minimum value is 10
